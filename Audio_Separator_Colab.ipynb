# %% [markdown]
# <a href="https://colab.research.google.com/github/Diakonrobel/MLX-Auto-Subtitled-Video-Generator/blob/master/Audio_Separator_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title Run the `Audio🔹separator` App

conf_end = "/content/Audio_separator_ui/.venv/complete.txt"
def config_complete() -> bool:
    import os
    return os.path.exists(conf_end)

if not config_complete():
    print("\033[34mThe installation will take approximately 5 minutes.\033[0m")
    # %cd /content
    # !git clone https://github.com/R3gm/Audio_separator_ui
    # %cd Audio_separator_ui
    # !pip install uv==0.8.13 -q
    # !uv venv --python 3.10 --clear -q
    # !curl -sS https://bootstrap.pypa.io/get-pip.py -o get-pip.py
    # !uv run python get-pip.py pip==23.1.2 -q
    # !uv run python -m pip install -q -r pre-requirements.txt
    # !uv run python -m pip install -q torch==2.5.1 torchvision==0.20.1 torchaudio==2.5.1 --index-url https://download.pytorch.org/whl/cu124
    # !uv run python -m pip install -q -r requirements.txt && touch {conf_end}

# %cd /content/Audio_separator_ui
# !uv run python app.py --share --theme NoCrypt/miku
# Out:
# The installation will take approximately 5 minutes.
# /content
# Cloning into 'Audio_separator_ui'...
# remote: Enumerating objects: 69, done.
# remote: Counting objects: 100% (69/69), done.
# remote: Compressing objects: 100% (42/42), done.
# remote: Total 69 (delta 32), reused 56 (delta 21), pack-reused 0 (from 0)
# Receiving objects: 100% (69/69), 261.14 KiB | 32.64 MiB/s, done.
# Resolving deltas: 100% (32/32), done.
# /content/Audio_separator_ui
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.5/19.5 MB 22.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 20.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 908.3/908.3 MB 1.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 115.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 113.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.2/133.2 kB 20.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 75.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 74.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 110.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 6.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 12.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 65.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.5/209.5 MB 6.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 122.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.9/60.9 kB 8.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 54.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 119.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.6/177.6 kB 25.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 90.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.3/16.3 MB 101.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 27.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 260.7/260.7 kB 33.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 75.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 72.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 11.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 32.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.6/59.6 MB 10.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.7/37.7 MB 41.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 101.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 69.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 38.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/64.7 kB 9.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.8/129.8 kB 20.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 283.2/283.2 MB 5.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.2/107.2 kB 16.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 74.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.6/95.6 kB 14.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 324.6/324.6 kB 39.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.5/73.5 kB 11.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 561.5/561.5 kB 47.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.0/133.0 kB 19.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.5/66.5 kB 10.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 115.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 444.8/444.8 kB 49.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 751.2/751.2 kB 65.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.4/13.4 MB 114.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.0/73.0 kB 9.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.6/46.6 kB 7.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 9.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 7.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.0/322.0 kB 37.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.6/181.6 kB 25.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.5/216.5 kB 28.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 78.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 308.4/308.4 kB 36.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.6/64.6 kB 8.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.3/242.3 kB 26.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 408.6/408.6 kB 41.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.2/288.2 kB 34.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.3/491.3 kB 50.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.0/325.0 kB 34.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 84.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 85.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.1/111.1 kB 15.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.9/229.9 kB 29.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.4/85.4 kB 13.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 152.4/152.4 kB 21.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.4/70.4 kB 11.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.2/161.2 kB 23.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.1/118.1 kB 18.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.8/78.8 kB 12.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 60.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.4/42.4 MB 27.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 509.2/509.2 kB 52.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 347.8/347.8 kB 40.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 16.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 6.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.2/102.2 kB 16.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.4/243.4 kB 35.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 13.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.3/87.3 kB 13.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 75.4 MB/s eta 0:00:00
# /content/Audio_separator_ui
# [INFO] >> Downloading: "https://github.com/TRvlvr/model_repo/releases/download/all_public_uvr_models/UVR-MDX-NET-Voc_FT.onnx" to /content/Audio_separator_ui/mdx_models/UVR-MDX-NET-Voc_FT.onnx
#
# 100% 63.7M/63.7M [00:00<00:00, 210MB/s]
# [INFO] >> Downloading: "https://github.com/TRvlvr/model_repo/releases/download/all_public_uvr_models/UVR_MDXNET_KARA_2.onnx" to /content/Audio_separator_ui/mdx_models/UVR_MDXNET_KARA_2.onnx
#
# 100% 50.3M/50.3M [00:00<00:00, 134MB/s]
# [INFO] >> Downloading: "https://github.com/TRvlvr/model_repo/releases/download/all_public_uvr_models/Reverb_HQ_By_FoxJoy.onnx" to /content/Audio_separator_ui/mdx_models/Reverb_HQ_By_FoxJoy.onnx
#
# 100% 63.7M/63.7M [00:00<00:00, 72.2MB/s]
# [INFO] >> Downloading: "https://github.com/TRvlvr/model_repo/releases/download/all_public_uvr_models/UVR-MDX-NET-Inst_HQ_4.onnx" to /content/Audio_separator_ui/mdx_models/UVR-MDX-NET-Inst_HQ_4.onnx
#
# 100% 56.3M/56.3M [00:00<00:00, 180MB/s]
# theme_schema%401.2.2.json: 12.0kB [00:00, 32.9MB/s]
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://55a385f608653a3a28.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# ERROR: unable to download video data: HTTP Error 403: Forbidden
# Traceback (most recent call last):
#   File "/content/Audio_separator_ui/.venv/lib/python3.10/site-packages/yt_dlp/YoutubeDL.py", line 3534, in process_info
#     success, real_download = self.dl(temp_filename, info_dict)
#   File "/content/Audio_separator_ui/.venv/lib/python3.10/site-packages/yt_dlp/YoutubeDL.py", line 3254, in dl
#     return fd.download(name, new_info, subtitle)
#   File "/content/Audio_separator_ui/.venv/lib/python3.10/site-packages/yt_dlp/downloader/common.py", line 480, in download
#     ret = self.real_download(filename, info_dict)
#   File "/content/Audio_separator_ui/.venv/lib/python3.10/site-packages/yt_dlp/downloader/http.py", line 371, in real_download
#     establish_connection()
#   File "/content/Audio_separator_ui/.venv/lib/python3.10/site-packages/yt_dlp/downloader/http.py", line 122, in establish_connection
#     ctx.data = self.ydl.urlopen(request)
#   File "/content/Audio_separator_ui/.venv/lib/python3.10/site-packages/yt_dlp/YoutubeDL.py", line 4239, in urlopen
#     return self._request_director.send(req)
#   File "/content/Audio_separator_ui/.venv/lib/python3.10/site-packages/yt_dlp/networking/common.py", line 117, in send
#     response = handler.send(request)
#   File "/content/Audio_separator_ui/.venv/lib/python3.10/site-packages/yt_dlp/networking/_helper.py", line 194, in wrapper
#     return func(self, *args, **kwargs)
#   File "/content/Audio_separator_ui/.venv/lib/python3.10/site-packages/yt_dlp/networking/common.py", line 359, in send
#     return self._send(request)
#   File "/content/Audio_separator_ui/.venv/lib/python3.10/site-packages/yt_dlp/networking/_requests.py", line 357, in _send
#     raise HTTPError(res, redirect_loop=max_redirects_exceeded)
# yt_dlp.networking.exceptions.HTTPError: HTTP Error 403: Forbidden
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/content/Audio_separator_ui/.venv/lib/python3.10/site-packages/gradio/queueing.py", line 626, in process_events
#     response = await route_utils.call_process_api(
#   File "/content/Audio_separator_ui/.venv/lib/python3.10/site-packages/gradio/route_utils.py", line 349, in call_process_api
#     output = await app.get_blocks().process_api(
#   File "/content/Audio_separator_ui/.venv/lib/python3.10/site-packages/gradio/blocks.py", line 2274, in process_api
#     result = await self.call_function(
#   File "/content/Audio_separator_ui/.venv/lib/python3.10/site-packages/gradio/blocks.py", line 1781, in call_function
#     prediction = await anyio.to_thread.run_sync(  # type: ignore
#   File "/content/Audio_separator_ui/.venv/lib/python3.10/site-packages/anyio/to_thread.py", line 56, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#   File "/content/Audio_separator_ui/.venv/lib/python3.10/site-packages/anyio/_backends/_asyncio.py", line 2476, in run_sync_in_worker_thread
#     return await future
#   File "/content/Audio_separator_ui/.venv/lib/python3.10/site-packages/anyio/_backends/_asyncio.py", line 967, in run
#     result = context.run(func, *args)
#   File "/content/Audio_separator_ui/.venv/lib/python3.10/site-packages/gradio/utils.py", line 909, in wrapper
#     response = f(*args, **kwargs)
#   File "/content/Audio_separator_ui/app.py", line 982, in audio_downloader
#     ydl_download.download([url_media])
#   File "/content/Audio_separator_ui/.venv/lib/python3.10/site-packages/yt_dlp/YoutubeDL.py", line 3660, in download
#     self.__download_wrapper(self.extract_info)(
#   File "/content/Audio_separator_ui/.venv/lib/python3.10/site-packages/yt_dlp/YoutubeDL.py", line 3633, in wrapper
#     res = func(*args, **kwargs)
#   File "/content/Audio_separator_ui/.venv/lib/python3.10/site-packages/yt_dlp/YoutubeDL.py", line 1657, in extract_info
#     return self.__extract_info(url, self.get_info_extractor(key), download, extra_info, process)
#   File "/content/Audio_separator_ui/.venv/lib/python3.10/site-packages/yt_dlp/YoutubeDL.py", line 1668, in wrapper
#     return func(self, *args, **kwargs)
#   File "/content/Audio_separator_ui/.venv/lib/python3.10/site-packages/yt_dlp/YoutubeDL.py", line 1824, in __extract_info
#     return self.process_ie_result(ie_result, download, extra_info)
#   File "/content/Audio_separator_ui/.venv/lib/python3.10/site-packages/yt_dlp/YoutubeDL.py", line 1883, in process_ie_result
#     ie_result = self.process_video_result(ie_result, download=download)
#   File "/content/Audio_separator_ui/.venv/lib/python3.10/site-packages/yt_dlp/YoutubeDL.py", line 3065, in process_video_result
#     self.process_info(new_info)
#   File "/content/Audio_separator_ui/.venv/lib/python3.10/site-packages/yt_dlp/YoutubeDL.py", line 187, in wrapper
#     return func(self, *args, **kwargs)
#   File "/content/Audio_separator_ui/.venv/lib/python3.10/site-packages/yt_dlp/YoutubeDL.py", line 3543, in process_info
#     self.report_error(f'unable to download video data: {err}')
#   File "/content/Audio_separator_ui/.venv/lib/python3.10/site-packages/yt_dlp/YoutubeDL.py", line 1126, in report_error
#     self.trouble(f'{self._format_err("ERROR:", self.Styles.ERROR)} {message}', *args, **kwargs)
#   File "/content/Audio_separator_ui/.venv/lib/python3.10/site-packages/yt_dlp/YoutubeDL.py", line 1065, in trouble
#     raise DownloadError(message, exc_info)
# yt_dlp.utils.DownloadError: ERROR: unable to download video data: HTTP Error 403: Forbidden
# Duration audio: 16646.2
# [INFO] >> Device: cuda

# %% [markdown]
# Open the `public URL` when it appears
